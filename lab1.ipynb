# %%
print("Hello, Sang Sagong and Max Zhelyeznyakov") 
import simpleaudio as sa
wav_obj=sa.WaveObject.from_wave_file('train32.wav')
play_obj=wav_obj.play()
play_obj.wait_done()
# Out:
# Hello, Sang Sagong and Max Zhelyeznyakov

# %% [markdown]
# #Discussion
# A comment of your choosing about the audio file

# %%
#Assignment 1

# %%
import numpy as np
y1 = np.array([4,6,2])
ca=y1[1]
cb=np.array(y1[1:3])
d=y1
print(ca)
print(cb)
x1=np.ones(5)*2
x2=np.arange(-2,3)
print(x1)
print(x2)
arrp = x1+x2
arrc=np.concatenate([x1,x2])
print(arrp)
print(arrc)
# Out:
# 6
# [6 2]
# [2. 2. 2. 2. 2.]
# [-2 -1  0  1  2]
# [0. 1. 2. 3. 4.]
# [ 2.  2.  2.  2.  2. -2. -1.  0.  1.  2.]

# %%
#Assigment 2 fs=2 x(t)=0.5t ,y(t)=t^2,0<=t<=3
#part a
fs=2
t=np.arange(0,3.1,1/2)
x=0.5*t
print('x=',x)
y=t**2
print('y=',y)
#part b
z=x-2*y
print('z=',z)
#part c
w1=int(2*fs)
print('w1=',z[w1])
#part d 
n1=0
n2=int(1.5*fs)
print('z=',z[n1:n2+1])
# Out:
# x= [0.   0.25 0.5  0.75 1.   1.25 1.5 ]
# y= [0.   0.25 1.   2.25 4.   6.25 9.  ]
# z= [  0.    -0.25  -1.5   -3.75  -7.   -11.25 -16.5 ]
# w1= -7.0
# z= [ 0.   -0.25 -1.5  -3.75]

# %%
#Assignment 3
#part a
import simpleaudio as sa
wav_obj=sa.WaveObject.from_wave_file('train32.wav')
fs1=wav_obj.sample_rate
channel1=wav_obj.num_channels

print('Number of  train channels=',channel1)


wav_obj=sa.WaveObject.from_wave_file('tuba11.wav')
fs2=wav_obj.sample_rate
channel2=wav_obj.num_channels

print('Number of tuba channels=',channel2)

#partb
from scipy.io import wavfile as wav
fs1,data1=wav.read('train32.wav')
y1=data1



fs2,data2=wav.read('tuba11.wav')
y2=data2
len2,ch2=y2.shape

#partb
play_obj =sa .play_buffer(y1, channel1,2, fs1)
play_obj.wait_done()
play_obj =sa .play_buffer(y2, channel2,2, fs2)
play_obj.wait_done()
train_swap = sa.play_buffer(y1, 1, 2, fs2) 
train_swap.wait_done()
tuba_swap = sa.play_buffer(y2, 2, 2, fs1)
tuba_swap.wait_done()



# Part C
print('Train whistle has :sampling rate',fs1,',#of samples',len(y1),',type',y1.dtype)
print('Tuba has:sampling rate',fs2,',#of samples',len2,',#of channels',ch2,',type',y2.dtype)

y2 = y2[:, 0]
data1 = len(y1)
data2 = len(y2)
if data1 > data2:
    y3 = y1[0 : data2]
    y4 = 0.5 * y3 + 0.5 * y2
    y4 = np.int16(y4)
else:
    y3 = y2[0 : data1]
    y4 = 0.5 * y3 + 0.5 * y1
    y4 = np.int16(y4)
play_obj = sa.play_buffer(y4, channel1, 2, fs1)
play_obj.wait_done()
outfile = 'y4.wav'
wav.write(outfile,fs1,y4.astype('int16'))

# Part D
pause = np.zeros(int(4 * fs1), dtype = np.int16)
y5 = np.concatenate([y1, pause, y2])
play_obj = sa.play_buffer(y5, channel1, 2, fs1)
play_obj.wait_done()
outfile = 'y5.wav'
wav.write(outfile,fs1,y5.astype('int16'))
# Out:
# Number of  train channels= 1
# Number of tuba channels= 2
# Train whistle has :sampling rate 32000 ,#of samples 50313 ,type int16
# Tuba has:sampling rate 11025 ,#of samples 109708 ,#of channels 2 ,type int16

# %%
# Assignment 4
# %matplotlib notebook
import numpy as np
import matplotlib
import matplotlib.pyplot as plt

# Part A
fs=5

t= np.arange(-2,4.1, (1/fs))



# Part B

w=abs(t)
x=2-t
y=-0.5*(t**2)

fig1=plt.figure(1)

plt.plot(t,w,label='w(t)')
plt.plot(t,x,label='x(t)')
plt.plot(t,y,label='y(t)')
plt.xlabel('t')
plt.suptitle("comparison plot")
plt.legend()
plt.show

plt.grid()
# Out:
# <img src="data:image/png;base64,..." width="560.8333333333334">

# %%
# Assignment 5 -- Plotting Sound Files using Subplots

# Part A
from scipy.io import wavfile as wav
fs1, y1 = wav.read('train32.wav')
fs2, y2 = wav.read('tuba11.wav')
t1 = np.arange(0, len(y1), 1)
t1 = t1 / fs1 * 1000
t2 = np.arange(0, len(y2), 1)
t2 = t2 / fs2 * 1000

# Part B
fig2 = plt.figure(2)
fig2.subplots_adjust(hspace = 0.5, wspace = 0.2)

plt.subplot(1, 2, 1)
plt.plot(t1, y1, color = 'red')
plt.title('y1')
plt.ylim(-20000, 20000)
plt.xlim(0, 2500)
plt.ylabel('Amplitude')
plt.xlabel('Time(ms)')

plt.subplot(1, 2, 2)
plt.plot(t2, y2, color = 'yellow')
plt.title('y2')
plt.ylim(-20000, 20000)
plt.xlim(0, 2500)
plt.ylabel('Amplitude')
plt.xlabel('Time(ms)')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
